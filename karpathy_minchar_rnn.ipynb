# %% [markdown]
# ### Implementing Karpathy's minchar vanilla RNN implementation in Shakespeare dataset.
#
# [https://karpathy.github.io/2015/05/21/rnn-effectiveness/](https://karpathy.github.io/2015/05/21/rnn-effectiveness/)

# %%
import numpy as np

dataset = open('/content/shakespeare.txt.txt', 'r').read()
chars = list(set(dataset))

char_to_ix = { ch:i for i,ch in enumerate(chars) }
ix_to_char = { i:ch for i,ch in enumerate(chars) }

# %%
# hyperparameters
hidden_size = 100
seq_length = 25
lr = 1e-1

# weights (randomly assigned)
wxh = np.random.randn(hidden_size, len(chars))*lr # input to hidden layer
whh = np.random.randn(hidden_size, hidden_size)*lr # hidden to hidden
why = np.random.randn(len(chars), hidden_size)*lr # hidden to output

#bias
bh = np.zeros((hidden_size, 1)) # hidden bias
by = np.zeros((len(chars), 1)) # output bias

# %%
def loss_fxn(inputs, targets, h_prev):
  xs, hs, ys, ps = {}, {}, {}, {} # input_state, hidden_state, output_state, probability_state
  hs[-1] = np.copy(h_prev)
  loss = 0

  #forward pass (computing prediction + maintaining hidden state + calculating loss)
  for t in range(len(inputs)):
    xs[t] = np.zeros((len(chars), 1)) # 1-of-k encoding
    xs[t][inputs[t]] = 1

    hs[t] = np.tanh(np.dot(wxh, xs[t]) + np.dot(whh, hs[t-1]) + bh) #hidden state
    ys[t] = np.dot(why, hs[t]) + by # unnormalized log probabilities for next chars
    ps[t] = np.exp(ys[t]) / np.sum(np.exp(ys[t])) # probabilities for next chars
    loss += -np.log(ps[t][targets[t],0]) # softmax (cross-entropy loss)

  #backward pass (computing gradients + updating weights)
  d_wxh, d_whh, d_why = np.zeros_like(wxh), np.zeros_like(whh), np.zeros_like(why) #gradients of the weights
  d_bh, d_by = np.zeros_like(bh), np.zeros_like(by)
  d_h_next = np.zeros_like(hs[0])

  for t in reversed(range(len(inputs))): # cuz backprop (bptt)
    dy = np.copy(ps[t])
    dy[targets[t]] -= 1
    d_why += np.dot(dy, hs[t].T)
    d_by += dy
    d_h = np.dot(why.T, dy) + d_h_next # backprop into h
    d_h_raw = (1 - hs[t] * hs[t]) * d_h # backprop through tanh nonlinearity
    d_bh += d_h_raw
    d_wxh += np.dot(d_h_raw, xs[t].T)
    d_whh += np.dot(d_h_raw, hs[t-1].T)
    d_h_next = np.dot(whh.T, d_h_raw)
  for dparam in [d_wxh, d_whh, d_why, d_bh, d_by]:
    np.clip(dparam, -5, 5, out=dparam) # clip to mitigate exploding gradients
  return loss, d_wxh, d_whh, d_why, d_bh, d_by, hs[len(inputs)-1]

# %%
def sample(h, seed, n): # hidden state, random seed
  x = np.zeros((len(chars), 1))
  x[seed] = 1
  ixes = []
  for i in range(n):
    h = np.tanh(np.dot(wxh, x) + np.dot(whh, h) + bh)
    y = np.dot(why, h) + by
    p = np.exp(y) / np.sum(np.exp(y)) # exp is eulers wala exponential no.
    ix = np.random.choice(range(len(chars)), p=p.ravel())
    x = np.zeros((len(chars), 1))
    x[ix] = 1
    ixes.append(ix)
  return ixes

# %%
n, p = 0, 0

mWxh, mWhh, mWhy = np.zeros_like(wxh), np.zeros_like(whh), np.zeros_like(why) #memory state
mbh, mby = np.zeros_like(bh), np.zeros_like(by) # memory variables for Adagrad
smooth_loss = -np.log(1.0/len(chars))*seq_length # loss at iteration 0

while True:
  # prepare inputs (we're sweeping from left to right in steps seq_length long)
  if p+seq_length+1 >= len(dataset) or n == 0:
    h_prev = np.zeros((hidden_size,1)) # reset RNN memory
    p = 0 # go from start of data
  inputs = [char_to_ix[ch] for ch in dataset[p:p+seq_length]]
  targets = [char_to_ix[ch] for ch in dataset[p+1:p+seq_length+1]]

  # sample from the model now and then
  if n % 100 == 0:
    sample_ix = sample(h_prev, inputs[0], 200)
    txt = ''.join(ix_to_char[ix] for ix in sample_ix)
    print('----\n%s\n----' % (txt, ))

  # forward seq_length characters through the net and fetch gradient
  loss, d_wxh, d_whh, d_why, d_bh, d_by, h_prev = loss_fxn(inputs, targets, h_prev)
  smooth_loss = smooth_loss * 0.999 + loss * 0.001
  if n % 100 == 0: print('iter %d, loss: %f' % (n, smooth_loss))

  # perform parameter update with Adagrad
  for param, dparam, mem in zip([wxh, whh, why, bh, by],
                                [d_wxh, d_whh, d_why, d_bh, d_by],
                                [mWxh, mWhh, mWhy, mbh, mby]):
    mem += dparam * dparam
    param += -lr * dparam / np.sqrt(mem + 1e-8) # adagrad update

  p += seq_length # move data pointer
  n += 1 # iteration counter
# Out:
# Streaming output truncated to the last 5000 lines.
#
# MACARKE:
#
# HINGONIA:
# Cail thim,
# Op: undy; byere with my hasti
# ----
# iter 80000, loss: 48.354838
# ----
# erpees
# O
# R:
# Oe.
#
# LESE BRATALL:
# p-yound to to mion twell aming, your susperd;
# Hake wy lers ang not favehes not hered-s fore in her nod butrer that glaunce, hall: an:
# The deam her doI-neto now in to tho
# ----
# iter 80100, loss: 48.274295
# ----
# eairee pidour dran, 'nlatping oft, tri's must thedy there; my
# plearniout we
# Tondure mand not, do a gulit in not 'stertefen remare, and are wather thou thre'th theemy
# Enty.
#
# TANAXHAR:
# Le
# Miny bend, but
# ----
# iter 80200, loss: 48.203476
# ----
# he plors courry,
# Or Huad. underssoncest,
# Mutiod wais Sirdowire, woults
# If Ged at upranders so startper fastrented tro a withre, doth it.
#
# BRITA:
# Thag louspidain sposet at visele. Gr-chat that watt.
#
# B
# ----
# iter 80300, loss: 48.197255
# ----
# hancon.
#
# MFATMATR:
# -veg weed grot, me bemesseand, gut, they, bus you goling, Hadouraaen,
# Lot broke.
#
# Dy, kingsed stound hearend gany spenst deratire fis, thise my coud affield woust--yatt minked
# mas.
# ----
# iter 80400, loss: 48.234811
# ----
# N:
# Bup bad
# What goldion, Pall'd swaurt domo
# The sall, in perist pretorl thes and se kingse with toung them man,
# Aneirn a bandes bus hase fills, the pore eralling soy thee.
# Fir inte inds
# Bordiours-beed
# ----
# iter 80500, loss: 48.209472
# ----
# e ith, and somy frimch it lord:
# Co pate;
# Marthcu seagh
# Anobgot thou neat theme desingo nod witurt a henle ruthoubt, her fire thou whores corle
# Heace tongersstone:
# Forbowithcod shateake,
# A
# Cup; atlin,
#
# ----
# iter 80600, loss: 48.252096
# ----
# 't hore, ay
# That, my this ry.
# 'hay, hery and 'erte's is to grove, my lase arar ovreentes nather fill gomde.
#
# Badr intsel proud MGlas cith hat three feorth owefon,
# The lick
# .
#
# Selor do I see up mangens
# ----
# iter 80700, loss: 48.195633
# ----
# eachen ball st ices,
# But hat nd dete:
# Wharruld in to chourele
# That be maight tinghthipbsyay
# Yous see tkonted'd thas brothour mine shenenthneds'd and thim, in of the wand your upalu not grapst thou thu
# ----
# iter 80800, loss: 48.254759
# ----
# ee run than and fer Jos the kant;
# A simust umesst confeants, and plis, he mee thy port panten gooke sy fangad, thus buescmany cadrers swince, mught to pruis cangerare,
# Sir? I ant you hish a mood.
#
# ORC
# ----
# iter 80900, loss: 48.191536
# ----
# chios,
# Heat an:
# Lo then
# Fir'wshe'st temor,
# Muply me han my lus amid't shold wavey
# OLH stat be
# The mase me, danw, my wearse madan
# a to whou the! couthber meech and him, and vorl thit word
# And Soars you
# ----
# iter 81000, loss: 48.217577
# ----
# tour of reming,
# I'rsws, hou to he styored's tre quelrow,
# And pleaind to thint'd not thasger are.
# Eake in douget tigephing that the Tull the waming dais thandal be, mike gordly eak sperad meest dee,
# Th
# ----
# iter 81100, loss: 48.124645
# ----
#  whe chainidby, me:
# Cour prece.
#
# GELYIV MAHAH:
# But'st frembe spain some ne he woook:
# I'll foos fore Eind.
#
# PARKI IA:
# Wher hork on wit
# Compert;
# Kithoce, sore:
# Oot
# That luge
# Neen's my laver;
# And Mighen.
# ----
# iter 81200, loss: 48.022091
# ----
#
# Ted islruting on with fair pronce,
# I weoner: I woll.
#
# KING ATHT:
# Put well aal in the ruck
# But I will cantain,
# I my gut it loth as so mandeing agrore rescle treatter's llennes betcow,
# The fualess.
#
# ha
# ----
# iter 81300, loss: 47.928780
# ----
# ou han morghted you, forake brind lit: hear Bes as moo go som.
#
# MAFARK:
# I hisich be Why lourad! stro! fave gopper:
# As: the,
# Sakest and I
# Most your I siend a vincout will ming a grimigs ghat sweet: and
# ----
# iter 81400, loss: 47.866386
# ----
# ot, owr lero fan not with opais.
#
# Thave He aul tinst greatyy unpear, fis ladiones dutare thou see a thie wh porend.
#
# KEN'd of near hight of pebeefls clong though aringhert, theses,
# Nelove romrad.
#
# BRI
# ----
# iter 81500, loss: 47.956888
# ----
# lfens the raghered whume with menake word knor. youn Sorroned to not
# But in are: my hell so londce kity you, my fro, and mare in the sexe in als your agion ach, and no do to wim cound ontuntt an no-Ch
# ----
# iter 81600, loss: 47.863183
# ----
# ns weirbwer?
#
# KESSIA AGf veres! him, will, and would I yoursur's le to the she we.
#
# OLAEANG:
# Yer to emast you they, a noturd your be the mairroivill the sacies, ce I surtver turd's in there, stro fain
# ----
# iter 81700, loss: 47.819572
# ----
# oth blotinty waldched lenlen's hill sursait thim this the wove frobust that and I,
# That trum's my soutse; unnill wit infiled hin, our foaked,
# Ye baskars and ives knlagress ISs eve
# Or meme, hicheernigi
# ----
# iter 81800, loss: 47.797270
# ----
# HVINTYIO:
# Ary'd,
# Thescants:
# Loth the dod hiich, amp. An
# Be
# oul shell withilsst that whing oud mongind me letour plish ay boyse on bes; mund not my are I heaky,
# Why line and.
#
# BRISGERANL:
# Yey, there po
# ----
# iter 81900, loss: 48.006562
# ----
# e a mparoaince 'stlagl
# Than I delathy it lith that yould misomingld am that him madion thicup, way the camin's boty your thee
# mers forgaty they,m
# Ther
# Dest to ald to appof.
# That liting
# To sheics't.
#
# C
# ----
# iter 82000, loss: 47.999949
# ----
# n il ous tootens; storts mast
# Es frouse reirand harleghore, Thear Mingut,
# Sonclodens vore yils gome then lown, all to ono a fornow theme wall'd lreave bloosiat the paiend hous Vagenere our
# For my thee
# ----
# iter 82100, loss: 48.127251
# ----
# u, ther prived sich I tise thim
# Is hoou's an trutrodl morseal
# crat neye noth, of the comberbups, a'd tallave heitibchind a truy the condon, they that dody.
#
# EIMESSIR:
# Core pertings.
# Le him thackain of
# ----
# iter 82200, loss: 48.131926
# ----
# out and But moat verhy and hagn, glaake aginee entle fall and swick's
# AR knou wall alait hithy ig where of thaj?
#
# HENI LOMY:
# I Vorderly! in the frow Lele of be ain yourseen, will a mang so Rich iad, t
# ----
# iter 82300, loss: 48.175662
# ----
# , will:
# There oult mear,
# Tay,
# Food non un mouspome, and jatoren bufes reglatter'ds in entey hem'd, hey the pill beisher gee not has us of it littounw nove you.
#
# ENSSTOR:
# To shick?
#
# SAGALEX:
# The betwea
# ----
# iter 82400, loss: 48.163573
# ----
# ar, an in you clay thy alllim.
#
# TRES MOLTALE:
# For have has in simm to memowr leds are
# Sip nove a dearcheriny
# Beare wellord!
#
# COONG:
# Somm'dsrefer In he kenst lordick cheie my to il ewady thet.
#
# GARY AR
# ----
# iter 82500, loss: 48.166357
# ----
# ve orld pace but be hersurm, the payer if exjo, good; ful thile more, goote my walk sill fere plefer
# Thyiltaul an his doonis bormorinell I ve me poon by ail her the reclaid out in ase fremengrown Oans
# ----
# iter 82600, loss: 48.260860
# ----
# ath not itwerent a se firder thind all, Coulmss, kion will some all your no sold beyous seve thisles whtleres itlucther
# nemo not lith itpour makise, not seavel your lood, unto guse:
# Selu,
# If sild.
#
# Ly
# ----
# iter 82700, loss: 48.192572
# ----
# w irfath vellot a gainss spane pean goove doy a mints and gathtion would partids,
# Reno fravato reaged as toull congery henedrigs dise wetury in wifice'st mow, fall Van aed in mey mugher:
# The wither a
# ----
# iter 82800, loss: 48.105331
# ----
# t hy wle a shall 'Tlith un
# Be us my wither lle ampy to mine his that femed this you hean thee wold.
#
# BRIUS:
# Court
# And speak
# Them fellst will abes I doiince
# The heak:
# same of devaend youm my hear, fro
# ----
# iter 82900, loss: 48.105566
# ----
# w sing
# Fit Tirst you the dongaon hey londine is your siring tould from age disfuld dreak, ail po viruldsen
# Tithe
# That tifcres maith I hird, ay, men to a dellod:
#
# For'tw mannerer
# Twa sarm have ott you
# ----
# iter 83000, loss: 48.156184
# ----
# ee Rasly wellr frimnes go se your moling thou, woth sits comw to palt,
# A whainey mrywed stucche
# Roued, all ut Nald yoth your tornas brim
# Cyoughase, with My 'pishally,
# Bagion prins,
# The,
# Thume,.
#
# TAETI
# ----
# iter 83100, loss: 48.243410
# ----
# ou st oinst mach dich ks Girst antes he waster has will to we mtyoin, for I sie:
# Wilgell meed sispulg, eremfarmyert, theme we of Thou rife our my sisset ase the dutince a day they semube and manstins
# ----
# iter 83200, loss: 48.170785
# ----
# y
# Cong I I ond tageit'd not demice eghin to hist an of know worr hake ars,
# I wobdy;
# AST Oramine we and the, I fied ueld reas megeer insurting casperent re.
#
# MEMBEN:
# O: Pyouty.T
# BENTNA:
# Tund's, by Fraw
# ----
# iter 83300, loss: 48.100875
# ----
# d arty tham
# bod ond murdy,, of cist hor I me and rabestely.
#
# CISTOS:
# Sow me, for I well pinger
# Thas in die, thaidre ang nour contes iak,
# But mosers in heyon this brupseeare he her, I guenswane this Ef
# ----
# iter 83400, loss: 48.003228
# ----
# ANIPHATRI
# LINCE:
# Beit ford;
# Am
# For trould downel, you thy fordshed you
# Butste, Thruch eraven of Cim
# Ithase this pobdotervrol the minct,
# As wion we my siran ard you sur the brow their
# Fon this my parn.
# ----
# iter 83500, loss: 48.082080
# ----
# outh oul an ve securuds hourthes.
#
# SILCIAGUST:
# A vearmerring bones be to toot:
# To ny lown-'at whack agh your mord abe would Tave and, fol poile,
# Eve such move!
#
# CAESSE:
# Bay and menserth, thou now with
# ----
# iter 83600, loss: 48.053051
# ----
# apored no thom nothy's to m.
# For then all are it daughands so moy cespye.
#
# CLENASARILETY ON CORRW:
# Nom Shever,
#
# ONREBr To Leks sar, die;
# Hary ponay; for are all tonst,
# And beyo iv a fielf lojentruess,
# ----
# iter 83700, loss: 48.199655
# ----
# e ion your and thand fein do the vire you and som wass reast our welll aldoneme Shall the seakth.
#
# ANNE:
# And then fingred to that theseare siss tleie not and what Mare troughtel themest hish he wolld:
# ----
# iter 83800, loss: 48.234412
# ----
# nethen villed surin thou rabet
# Sirvan,
# Uo
# To are gidis hew, modsan we wopsarts:
# Whese sans, sare puld well of the with stay and you seme nethces a fild waje gernoust that les a loscath dechilnowe.
#
# RR
# ----
# iter 83900, loss: 48.341598
# ----
# ood fain. facround hat but, whou have lest to swee, dange, by her des bromed nerephingmes will this be brrount the daire not the sam 'al Fransclith I arnit dessty, is of tisis Goath
# Thou wouldodh my,
# ----
# iter 84000, loss: 48.192940
# ----
# :
# Oll
# With Manqureed?
#
# Re, Thy seard contess.
# When
# This Conse, thy would wull haved Lut in gro.
#
# ERHTRCK VANOUSTA:
# Betting
# The werseff foubd wave but trovesty theel my hather warm a tryell our thou kn
# ----
# iter 84100, loss: 48.135283
# ----
# ee thak lens as it hiskly Gut, wlust perke, told chet,
# I whe a lo paig could cleat shall eriw would bram that dot saw for his mintgy for sair
# See I shap ant it fur lornech and fors nfour Es a die go t
# ----
# iter 84200, loss: 48.042367
# ----
# e istoys mye youn haves bayerss soakn
# Hot dim frum I my fornd I'st indencatre.
#
# DaES Shro heves hot
# prath doin:
# The wall growin swayfl esse, any dewt heonS and, I have theme shaw we to bus the dossing
# ----
# iter 84300, loss: 48.024758
# ----
# ou his crach,
# I will a frulnod shee suld thall thos own Cins,
# Arseffionty briak noter
# Fig:
# I mort, she it ho loung con
# Nt thiy to senat the soen,
# now my londet
# Whownore,
# I bets, the pandire remonfins
# ----
# iter 84400, loss: 48.068353
# ----
# 's fih hand!
#
# TwILLAN:
# But sigef wase Ot we lorg thonce?
#
# BEDIO:
# Mive dim thee:
# And say the fires; aglow,
# Thin you
# prom, oun suchechisesed for now we gartar our. Lise our hteys thist the dig, and hade
# ----
# iter 84500, loss: 48.046607
# ----
# share by hath, Lare ray
# ut pard lond,
# I hislan!
# For Thore corngealc
# II fryebgenge but gith pundingse:
# A bhy quenter thou fllarver beeadneroth all fir,
# San poave thruat,
# Martion'
# Whare I wos Fow at the
# ----
# iter 84600, loss: 48.078384
# ----
# oul all bur stuy dith sion, wet these moll uny reaves and siet
# Thine in with you corfow
# Bet dnate;
# As hist lold.?
# 'y, his my with kity:
# Mind not hat bank marty your glemes grlengle ich of unty
# Stup:
# B
# ----
# iter 84700, loss: 48.040996
# ----
# AJANTTR:
# Hiw spuind.
#
# Fores your hather only ly so she molly grastry!
#
# ALVOLIAHANF VICAH:
# What sabre thou dras?
# Than horise tlyoued, and bood our dace aroung condry the minusford,
# Trom mordwer come wo
# ----
# iter 84800, loss: 48.084691
# ----
# our fore twough thou mare od coman scoth wits.ow
# Tortent there-
# geavest, your no' unpap and Rastlees ar, thy fersher spich not stand confund ding
# As
# Apart
# Fors, soction 'ither in of so ald cikl, him a
# ----
# iter 84900, loss: 48.027771
# ----
# r hake butm facule, sow,
# Marmiy's so with indule batt thus the preakn there't louldss.
#
# ENRISS RIO:
# And then lire mant not no thy foare thou dis, I waw, fe domy gunter hill pirust he tinceline
# Thao je
# ----
# iter 85000, loss: 48.061033
# ----
# .
#
# Oad some bemergoprelin, Pipten more, 'we de:
# I hilnk stenter kinntut; you if and Ot this lord!
#
# BEhtZsllat-nath winnt mome: thinart
# The share marise,
# Cone dane Opis may do all the gle
# vires gross '
# ----
# iter 85100, loss: 47.964951
# ----
# y ffin fob hearsser obad pair
# Wequy in
# Bithy golor a prain with now, bear
# Mrabe.
#
# CASCESNY RUTOND:
# As se veur xoolp, all thet, ear king ineet thes. Peausw!
#
# Firsh ncomy to moann, go minet me
# Ree;
#
# BAR
# ----
# iter 85200, loss: 47.859336
# ----
# le
# wiet tarnen,
# Thee thou in your freact ske.
#
# MAdib it thous my? Brucu.
#
# CLELE VEAB:
# ALd,
# Werrolday untton why highersire, floblint.
#
# BOOLA:
# Co-marmes in tood,
# Non!
#
# DOYFur of be welling le twom
# To t
# ----
# iter 85300, loss: 47.771915
# ----
# Itheres fare true.
# 's wir a tole goon the'lf tike.
#
# OFOLA:
# What entryininy will I hir you upef till the sucre-dies
# Mfouss the cemolp snould and spact on mis'd pertingod mbjus in thoonkin my of gookl j
# ----
# iter 85400, loss: 47.729800
# ----
# ere ire gingranmy the deak whothere;
# Ar thot be subsakes in
# ReMuseth ay sine congola.
#
# IFryou say whe kine wim my lord linent way I wais you strine I allI now I wim stought dime
# I hersert lifm gan
# the
# ----
# iter 85500, loss: 47.791557
# ----
# he for ings Bnoblus rach and sholk enand haik and the por?
#
# KENTT sI havenes mive that hise a lion but all;
# Yat,
# Thas chal cake I will and this opal tourd minst will sam,
# y;gis necom 'eent thyust werf
# ----
# iter 85600, loss: 47.705879
# ----
# kes seen!
#
# LALVINGE:
# Whacty you and to no ments, sir,
# It making true, to now wup as he ingle Find you stack, as comoblups, larest I bly.
#
# By I's to no gle dreeert be to plas malu do that owen surtpine
# ----
# iter 85700, loss: 47.671159
# ----
# othr mabe deertifion, sien of I batter:
# Here their now char,
# And wore of his that them.
#
# SRANIMO:
# Shat that thape wat the hars:
# Maltt ow
# browmsare ranch a gut; a porme.
# But
# Stounes lo beaves:
# And lrpo
# ----
# iter 85800, loss: 47.630128
# ----
# R:
# Tak ming betrechy your unobe hey we baser:
# Ford, is thail ut gown the good him now vly,
# Muld sunconce Carnulle breems, there shak Co whinake me own you now thall wore, I forlid,, plefoll,
# Be and re
# ----
# iter 85900, loss: 47.847538
# ----
# ALESY:
# She hough'd he ouse our lathilf under
# M-is, as shanest guve!
# Whot som
# noe, witll ame thase
# nous a london comouf mprouch ler,
# Ale thy ruse
# Anl
# To ere unowingsn.
#
# CESDIA:
# Thy whate ather a rivert
# ----
# iter 86000, loss: 47.821659
# ----
# ur and your thes sithy fould me you mand of sucpyel ap berstuld to uss fould thot byy and Tallited:
# And fien
# Bem, my evelsted nondhy oneed wappe and of hor bave
# That voun, goor: and that have wach gup
# ----
# iter 86100, loss: 47.968753
# ----
# otho sha mdwers not ay the alk cearave sar goon miilsm off sear a siing dyous for, eteig,
# Thine selll the fulfare hour my lord the sen, weer,--h als ance;
# Buck,
# You go falk. Tod,
# I brryoul us the prea
# ----
# iter 86200, loss: 47.970204
# ----
# lost thon rake the on And whinepGoved mavenes for stsusce:
# An thowe, go dight stount as, my grome.
#
# CALLT:
# O:
# And shall the has sees thou arnows icher Mulder hare no my all
# On was mercaight.
#
# VENHENY:
# ----
# iter 86300, loss: 48.014672
# ----
# ayown
# Be, purnaje I gorldales, what his hathed have maded wiml aurt gook ses the caer's con.
# Tow not be gort:;
# Omy,
# Pancaudvew nemay's thee, whis everronty him nust ce we netilg then, spingle To o Lhu
# ----
# iter 86400, loss: 48.009707
# ----
#  thac manf of prat his daded or come truep: ky are ploing
# Anigh. I ble, whise? gith not so lu and not julce couver, warly kave ofl, usemes blens that's the cond:
# I wim my eat loully madrell and thris
# ----
# iter 86500, loss: 48.016042
# ----
# ep; fromend byour instrature pone rige if the spomy;
# Hibe 'pos wourd wich thee,
# A
# Hat frem but tith ct fave be out: mowy to near.
#
# HntRRMARK:
# I bey his muntary aus, me unce pradere! The moreme the Gac
# ----
# iter 86600, loss: 48.098600
# ----
# nt be ler-peasiong brove, that tom
# Be erele's not anday thot of here folliouss.,
# Wad buto aks, woud a brow? fore icu,
# Wos this heve fin I with.
#
# PINGBROPO:
# Thave of cante
# The Tace knour.
#
# LARTOD:
# And
# ----
# iter 86700, loss: 48.028195
# ----
# e ith Trwemay a pervire,
# By Tive?
#
# SoA fur do inece, and sine, the cheis,
# I heseavey; a folater fin forbers, wheire! thereare shee have it now thim form your in strate!
# Heneedar tirtil opt hearneld
# Wa
# ----
# iter 86800, loss: 47.949351
# ----
# e in greet,
# Ibe but and can!
#
# ANk ws INI:
# The have go but the tender's to whot cor, its,
# Lerep.
#
# CLEPESCEOY:
# My the waves town evindse, and shash manghy
# Tist of anjy reett my badlest ar in maid give t
# ----
# iter 86900, loss: 47.945611
# ----
# veptoll in owid!
#
# KINO:
# Witect of an that: him and blall in qair, the bagace that?
#
# FORIAGH:
# I
# And rese fat, trume's af ickring chabdier'd
# Fichied the cayount
# ure, the and are the eriter thel tighte.
#
# ----
# iter 87000, loss: 48.015906
# ----
# nt han,
# Whall till me
# Tall witly helr wetsef shall ce to uphcesed sall; ats; this nomavey to he thou and thke lork, y'll haig:
# Is to ervarrus fis, and moud falt:
# Sim heare, gruthath'st: Oneer of badcu
# ----
# iter 87100, loss: 48.091679
# ----
# nt wast cages mught fus a deent wero bord ay for It list earther stratst to and
# Tertolf with us my per' ce confurf, and thromn: at pompore us by heund is heavind
# To fputheralblor sh'll:
# Ee moo thou th
# ----
# iter 87200, loss: 48.013480
# ----
# ee fotiscud falls and yvus and canco mincle the dore and lors!
# Will ferm and aurst,
# Wholary, in'se:
# Leal my efrectorad
# the doand as bets no shacesanetht theed san your jocl,
# Theak,
# Heathers not see
# fr
# ----
# iter 87300, loss: 47.944349
# ----
# nefer. thy severy of see: and my moval' fee velive banced world to his like your seaveray thou thee
# Ung, thig dour lasty, bue natiet,
# Whough. Pos sut's ould.
#
# COESENE:
# A nowm broke.
#
# LALPALO::
# Flein.
# ----
# iter 87400, loss: 47.858588
# ----
# arto manente.
# If ondors; pleened prond, abrow, saestan's and ban seet.
#
# ALVAUSCONY:
# If i'senweds,
# And at toere frcecood,
# I forseet:
# Gake mente,
# Whet magut'll shim sand.
#
# LOSHES:
# Hees:
# Bupes ruce for m
# ----
# iter 87500, loss: 47.939898
# ----
# th
# Heth tur hercenowg to alf lowad the shall me is wit toon culsy rowning not pimopen sandeers, thou mo. Werd preerare ithest do demuncsuled, edsef for hifcrell
# Till nath bithf, hopind not
# He parbucto
# ----
# iter 87600, loss: 47.905345
# ----
# ISINGEN:
#
# Ibe condel' I'll sued fives have as thy hlay.
#
# VOFflEp
# Is snoull brones, you Soly woilds, that cunder:
# And fame and ack, if and dan I would bet 'ce a dlithy.
# Tay?
#
# TINIUO:
# Preme, ank Os fayc
# ----
# iter 87700, loss: 48.045029
# ----
# ereth ours, Sup, howt.
#
# GAUSTON:
# Soft,
# And we me is word, It?
#
# HatPITht
# Shat and maced; and wesare a love mank thav thandise this that jealds.
#  heay thee:
# A wove larthel sall see to make take our They
# ----
# iter 87800, loss: 48.088030
# ----
# he ware proth if bened'h to mairsp,
# Op incie and youn sese cletred?
#
# OF AMMAL:
# Is pall Noring henous hentld and all I be your shightry, yous.
#
# SIIUTHO:
# Cheny and a sween kinge, the gromus wefounter
# An
# ----
# iter 87900, loss: 48.192034
# ----
# ar boring to swearnth there
# Hey digd matul' memin theo and, puens ney paibid as how beeper a se ders, diptth than I will prith of thy be our oh enowhe, fur derghy Sorlcan to phad and some steruch her
# ----
# iter 88000, loss: 48.068935
# ----
# hathf onUt haves, witly statiel: if shaig. quyelity:
# But hist'd bone,
# This hat be hisw, in a geothed, whave tull hose ines,
# The feaks aod your tondon se
# To eae, a daet hive Mnoure, sick,
# To die to dyy
# ----
# iter 88100, loss: 48.087784
# ----
# Gameus see this wiflle of and mane be
# I
# Difet: nereir,
# Yowe sofel Be Youter,
# We love have your le rto ilf doth
# As at your Lorlt thave gadge's Centept warkew herised:
# I fenothers with thet theud I's yo
# ----
# iter 88200, loss: 48.037964
# ----
# was in of ush yotre: Norrous, raysan then my on hilks fold budwel to budssay sese, born me if and there but not a they' trentin evenceds; and bet and Pase
# Le loncle all preet tourtlom's to megantien f
# ----
# iter 88300, loss: 48.118607
# ----
# UCHIORIAUS:
# It fervane the mous miltser not 't exseakeringed my coulf
# Wabd the capdorb of hathed
# not till erare, mueds preens, by thy ane herle, thmast drinourn; well loung hal so is praine
# Le boobghi
# ----
# iter 88400, loss: 48.242345
# ----
# nethe racky ho me hat; are in a doadro his elangld,
# I form hould,'d puppeanger:
# I'll now Pray, nave hence hie cay, I hainet, knone
# To foon, sho puch'L' fwaws to day there I seuggarm poen: you has them
# ----
# iter 88500, loss: 48.253978
# ----
# tourd.
# 'obyep you who ild a fure to-R,
# How a
# there gut compeare daw, and agrephain yous me galus to sttaie ane, drincm us of Fortt no ghac a lise ald your drath as I what mort, I seges je.
#
# AVBOLOFED:
# ----
# iter 88600, loss: 48.367615
# ----
# ere's fur dowseardan apainles fraist.
# Las ot bud us ghas wim,
# That hact:
# Wered am bevrisnet:
# Oeise taie rand bapseet recpeat berabjups ame the out why trot memunt not all. But, thisar uplits my
# To day
# ----
# iter 88700, loss: 48.407621
# ----
#
# Wil,
# Thine the eldwen and shath me
# To wivet sithin the crofoudess a semolept yould. For she ta care von a thet and to sear thou surse fatbay,
# Hoven took make in the chefer pariwst arugt blood reveren
# ----
# iter 88800, loss: 48.470640
# ----
# ou theserved air pentows is ar lors,
# Non ulleer, they,
# This of now not hainchirged tand.
#
# PRY VICLIO:
# If me comcingear not was me thall you the will Orams, han thay vars.
#
# CORDRE:
# Mayedg.
#
# LEBRODUS:
# N
# ----
# iter 88900, loss: 48.443574
# ----
# ot, ofe,
# I nat's nfwown,
# I hloed an as
# Tany's and thyor onds, brtosh not chuis, your I my sfange all ey, byy neand and prorte ersese they whaine; and moing hea with planplemp'de,
# Wess pranet what vile
# ----
# iter 89000, loss: 48.494230
# ----
# I's dringurckert-never that movey's ive quith remendind litowray
# I.
#
# Semy pill with thece.
#
# OMANTENRENTHF UABE:
# Lath weast of
#
# EPHIUMINGYLIOP:
# Your nos ety ceat as ad inle and with you:
# Whore, we a ce
# ----
# iter 89100, loss: 48.432874
# ----
# cashe,
# Ceef taeced cest be knathd.
#
# PAMBISGUCS:
# To tile my an be whe purselo yecny, not to the ale, I habden the a cith It whut.
#
# Selll not thet lord.
#
# PRIUTIR
# A:
# Why somes s, the aulns as swer hap so
# ----
# iter 89200, loss: 48.342363
# ----
# ur and felly betrinnow bavper-And not sispare cretter, srathn'd you of mar's may be ame enta tens and shall thing epent; Ot braak.
#
# DESYOUTOY:
# I ie to to thingen ow my mante ristlall hove me lidale th
# ----
# iter 89300, loss: 48.277066
# ----
# e feasist go the my ran hom thou swistle
# Betse? I hact soos higs;
# Hatunt preathar and, it if sactere rang no a reveres dy,
# me,, fince and a fealk prade and and your of thet to caspoy his, your fervorl
# ----
# iter 89400, loss: 48.242452
# ----
# OVENVY:
# Vincher, haseld in he reack thee suck'd not waglo
# Thyery lord; goot titt wangaise: and, dearend. browg of lave anowfote
# Wradst my lour by erisfork hage.
#
# DATIO:
# That go muse
# For and you, for a
# ----
# iter 89500, loss: 48.316522
# ----
# hack thou him's last as thes bots?
#
# SUSTALIN: thin by boved to likeffangsny with your reat not thou ther, vieshy
# The fill trumt:
# Who' dro besse are the faines hink:
# madyire lope im well what wiflowe c
# ----
# iter 89600, loss: 48.294060
# ----
# rif orestuce.
#
# BAve?
#
# Thou good of no younal' and as this hee are the with ow would .
# Ba thise but his spoor,
# werly prath be you's dyed centhy swir?
#
# APRIUS:
# Thou sowt iell whild the pich frotone.
#
# MA
# ----
# iter 89700, loss: 48.273858
# ----
# r am,
# With prathigh.
#
# ULECKINGHAEMICIUS:
# And be,
# Worlb
# Otowt?
#
# KINGER:
# Sen man Croce, the kine make.
#
# COOFO:
# Fors?
# Sheronof to congooul,
# Ho binggevret not speld thir, be a will
# I have and taadins nigh
# ----
# iter 89800, loss: 48.256815
# ----
# er wit nown dathow,
# The, shasent
# Braem, styost to my le, alg and leman I tofy in tlaigher? now as nos bade ands to mans, burge:
# Whe baty remour's Sill gaome neyies everfefon that whir fere
# Tarmase ars
# ----
# iter 89900, loss: 48.472065
# ----
# vime: condes ther ofadbrorr,
# It all I my blood wher's grwied hotret?
#
# LEPENIUS:
# As there a thip undour lloobaereld senclas in on thinged in woft shess 'arter my fer voure sit
# I love not neart? mach la
# ----
# iter 90000, loss: 48.461946
# ----
# nd have it ase.
#
# DUKE VOLFOLI
# A:
# Sam cusser go Wrow bith ereavest take a wellat.
#
# TRACES:
# You dour wey Gove Ally a deakn his mest sit thit there do Wild wead the fath the arv on sishe have high; Shiin
# ----
# iter 90100, loss: 48.565791
# ----
# Sanlire.
#
# Pyought there the virtir, ept to tretres for ingle.
#
# KINTr it condhe compey at the that all wither of then a full derech ootse ta thine oot vike now's mest celdoy we a waughime
# brand kigp, b
# ----
# iter 90200, loss: 48.602279
# ----
# our vir, thow, sukt rutherpces,
# Egh?
#
# SW lIMIO:
# I wor din whoulent:
# And munn! your stins.
# Sill I would I?
#
# BALTRUNN:
# Cow could shoust! it hon radrong Te hould derakes ot and knoud's dlasteict:
# Byor pr
# ----
# iter 90300, loss: 48.692078
# ----
#
# What worlcaie vice clitht the woys.
# Steedsare for hille heed eptoth you ched thirques is blie suppty ares and kids sam I bast done Jotstade be bances yabe, and not rithatringer, fere and go hat mamif
# ----
# iter 90400, loss: 48.677055
# ----
# p bear by rerveay, or
# meld I priy corle unown tood,
# Give But eampereniour thou worlis sum; the gony' and this in hay; your dechfull monced, a llince, wefen, cland have
# Wit wer.
#
# CRIM:
# I had,
# And and f
# ----
# iter 90500, loss: 48.695751
# ----
# he rear he jonte, ane enyount,
# And, mige vero moat in thriod, this prave styeanto no kere wiffar, I lliin a vircerelsd thes, beed that troun my some Casseart shaughus.
# Whay the preanball in I you wis
# ----
# iter 90600, loss: 48.750780
# ----
# hathy as har he fuld gotly, ook ut is bruch tlaush a lade to thy coxprets in your wither themage,
# Sor fore, thequuchy:
# Thuch swouldeas wherorre Shakin so then wonath now so shams,
# Whees toe mo
# gher we
# ----
# iter 90700, loss: 48.694689
# ----
# tr weild her his lord it daft kis shom dake, his ad obe the hrest yap have the essty's cher, Of thy all neer nabe our besboty go?
#
# DUKES:
# I any ambrot your I be a here in and tanke, hell thy syough'be
# ----
# iter 90800, loss: 48.579589
# ----
#  hase she le th.
#
# TIL OE:
# If would, muty and; then a rones ans
# zeriend inthbe pribgend affure ow gomdy
# If as gook with my laght:
# Delles preat beg;
# I woileritas the minly?
# To be virtion moring, are tha
# ----
# iter 90900, loss: 48.543680
# ----
# n, het ind. Somar.
#
# COCLEO:
# Dise go droute, as lold at paaus? wit hribly thit be coedicting,
# And riment heed to of wand ther, and lirth judy migcont dith couch here the harbes to you, ald peath, whem
# ----
# iter 91000, loss: 48.641883
# ----
# astry mese,
# Wad saichy you nowsiow fursent frobe, coefinge our to to with vire'd witly!
#
# KPLIO:
# And suchs pastiont no shother'd I done besctur poisce,
# A dice dinghy ever that have extrand,
# Line certer
# ----
# iter 91100, loss: 48.725533
# ----
# othh it comnces? whould and arduch youg sesses my sirissy a feearfelf its enting hine lam I milst this a and Thing knay, lither tany mest not Ley his as it seept ta herselL
# Bryour prapser, for a lasg
# ----
# iter 91200, loss: 48.661628
# ----
# nt eant wimghtud seest abatherie shee in is all whins,
# Golder-bertes mast,
# I well forgher; with fere inculy, anmed this fromb shay; thelionting.
#
# SilM
# ButG falles; the saster's 'Lortiod, and issin cou
# ----
# iter 91300, loss: 48.583210
# ----
# n
# With leviend as artly
# He, whould hast, Stied dofe, yourd
# Ifmane; hishiseavlant! to thy repong fuel for wable weak sherselt
# that ame, welo for dy twep't would with denint as poot; take, and have of t
# ----
# iter 91400, loss: 48.483278
# ----
# oli fing lle Forn friend I freys? geved waud; sooch of syothr: thou ce breest the.
#
# VARGUS LOLIUS SAUDAL:
# y, soce starves nod theave neave thre moglol one falles, cand one and have more cout kunours d
# ----
# iter 91500, loss: 48.537453
# ----
#
# Fir thath and ecrermand to poight not we to ware are cour not deather I your wife mort, tondake out heress misty my woncuy, in
# Witiouce so ente. armorork not cire of you hor,
# No thy fue.
# Fake come an
# ----
# iter 91600, loss: 48.511440
# ----
# wathir:
# Thou
# Wthe icus me on and wacu that not receak fors.
#
# TIDIO:
# And enonst form oikt ginty you plour whand;
# Axe and our comes:
# Aer-sice.
#
# NESAESIO:
# Nacky was stoomp
# Would efole'd strom wet indowel
# ----
# iter 91700, loss: 48.634041
# ----
# ow ir a satowrs tiats agboy lagghy
# not this swe doke my itherecherow and
# Form
# Nourt trake word?
#
# VARQOICHET:
# Make me mand lall the cansingiraver agerse so sme she lase in.
#
# MALS:
# Shat; comting houtter
# ----
# iter 91800, loss: 48.671140
# ----
# N:
# Mik inspond quenft's Gut and to awr ha! quered, sie take mepuy,
# Was suld
# botis, of hear a paat will do'th on ses me my gore
# And sa moruch ang he of lotund shig, thoir.
#
# EADDONG:
# Gur the netion's co
# ----
# iter 91900, loss: 48.794966
# ----
# ee with of thie all this king he dim destred the surtre,
# Hur as par ucon not nust
# mat the lord, as death this a must?
# But onge; cormmed ad to a sbost as
# crickes Thore doforty could wan, mather singre:
# ----
# iter 92000, loss: 48.636186
# ----
# ham ford;
# A erwid, weromy ames dyan doothy:
# Ary.
#
# OTMARUF OF:
# Be with thou a my the all secle live, suckande, thou .
# Wherr's hick een beds Cie
# Thy he wald,
#
# DUTEAGH:
# Nom
# I knoy joad this have ereb'sty
# ----
# iter 92100, loss: 48.556561
# ----
# y! fach tom swire:
# As
# Heartny;
# Thy the reved fayseetf ag't searcean, deawn to his uplend I vioth, in hould will swer on, wish stouw wrist the ves's evady, dond, the jugh a co so fill as
# yous a thin wh
# ----
# iter 92200, loss: 48.402457
# ----
# y with's as shall and mond pllumm,
# Byecher'd halat, if there elation.
# File sust of myar-myering. Turhouren, what we bloth oth, Murting of cout in the dearth!
# Shave for thee-
# an ourses indebim and go
# ----
# iter 92300, loss: 48.412735
# ----
# u, of whingo was and Gros me promage
# fos goat, be Tuct. Yhen, entratont that now I cemenw vealtror: be on coure,
# To a das a morad I would theran.
#
# VIOS:
# Whee am sane we let thou haves to oy disse
# Anlo
# ----
# iter 92400, loss: 48.462370
# ----
# ow, rear inged hombe lithel dence my groth-'spoll Fare, soI, evel plaust itwe:
# And frighuch shem's have heids tway, mise trewse;
# dow jooke tourd'shice
# Ey cowne;
# Ands
# Ollesh you upown morness somen,
# Bu
# ----
# iter 92500, loss: 48.416828
# ----
#  owre thingiomed:
# Thet tought spiers a mades by.
#
# PSANICLINY:
# I hintitet by sowar bade he sigemer, house by lowe byiot trus maconist a
# kt all prrigkt.
# AT'd thaw the madibes hine leme, stheath do tith
# ----
# iter 92600, loss: 48.483006
# ----
# hathowine duck lich,
# set enters'd Assleg.
#
# LEBROST:
# Whol horse que in was my fanthing such all trucher;
# For ritly and sus lise, tidtain, singents:
# That be Engon praft for lad remy all.
#
# KEPI:
# Thee and
# ----
# iter 92700, loss: 48.478508
# ----
# thiezlint gife vurdbeul vilthe them co then, sored, my in my a mescjyous infe love tile brostur. the of in the pipuhis, ento thou surcont misis I plot, shitly besteet;
# Ant he she me! Sorly.
#
# Sor good;
# ----
# iter 92800, loss: 48.493104
# ----
# othray: do bleap heme he kingsy made
# Sieven.
#
# KING RSIS NORK:
# That, fro' maisseest suffore, snath shain thy ver fore grought unterse
# To no gallann
# Hess
# Make heard tourd you with yot, my came sharnme:
#
# ----
# iter 92900, loss: 48.430542
# ----
# ee porser.
# If here condod
# Ese fortrour unfir sell, suve rither hath bentlit
# O to bay follep; owd there as shall nod man wit.
#
# KING LANY VICIO:
# The pithw bedreave and 'tien, my seatpen?
#
# ANGELIO:
# Cour
# ----
# iter 93000, loss: 48.466270
# ----
# Zham I love we charth it for cost of ard tro s'stor caldain, I will yource and this deveran.
#
# BOLES:
# As
# With he leat to be a sice
# On seatt; for of prame, me, of the forSe twause good bath,
# I joce apon
# ----
# iter 93100, loss: 48.357340
# ----
#  mamch thr moore,
# Cind for lathighfind, grom
# but wis, vord,
# You thee desing you your fiviat: with that
# For, wither the
# Ssongeser,
# I
# And in unding it shelly:
# Co your but,
# Lare: and brick:
# Le linggumbno
# ----
# iter 93200, loss: 48.248492
# ----
# erion, 'thras,
# But the hit sapt pilis of you Maust that way not esty pagentinods that mone loou,
# And chceais's harm-siot I will besings. Sheater eotper, syell I lord you and on thy ut and boesares has
# ----
# iter 93300, loss: 48.164645
# ----
#
#
# Credry jose I rathy thou selles they this broughin:
# Thare wall nereave het thoo.
#
# TRATVINAR:
# Whathary lowd wifteffol,
# Hown seat bood, cellet hand.
#
# APROILHOHIO:
# I' have of hat torbest of poofout thl
# ----
# iter 93400, loss: 48.111201
# ----
# his yciee and mance.
#
# CAGBMINEM:
# A dond;?
#
# TILE::
# So huslers sties shom in no out and, for in hy pay;
# Hears the a ill go but mepteed brervile, some, taturce
# Ald, for me.
#
# ud reus quenerine my adrs, on
# ----
# iter 93500, loss: 48.169349
# ----
# hatlor etoces,
# But which some.
#
# OFARAT:
# There and ang your when aw us cournat your then, in elish on weus.
#
# Thergme,
# but,
# Weast he mace
# Ther, Iplerse, are?
#
# Feres st cecofore the dyoffefany Theses sha
# ----
# iter 93600, loss: 48.123797
# ----
# l ran entore thus to as laghile missersce shard,
# When our in thy his, losd the! Me you thich and hoth on.
#
# DUVRIO:
# O you the wand thou she pan thed you afouce or the her condar,
# Hillese offar and
# And
# ----
# iter 93700, loss: 48.099511
# ----
# kere Sece unowel:
# Sookecther as Girved would of dy,
# Hord; thes goon
# I promp, treat by gothen it semus, your will shae bife?
#
# ANDEY:
#
# PLICLONLE AT:
# I be obe
# Cour think you mussareed I mell are aldour b
# ----
# iter 93800, loss: 48.079482
# ----
# refoll
#
# MANELO:
# anfoln, alold, out youl these lerray for a goody these kingant dife as to deave not thot serserter,
# Thotrowy fare I ce fring sand have?
#
# OH
# FPRTARIID,:
# If Andet, I hap,
# Heariget mu dea
# ----
# iter 93900, loss: 48.286913
# ----
# ncion, not and su fare an my but I roo maked shall conte coutsd rees prit hasis his fult tus noudsrand mugay meptre
# st to the kneime I scime yor he that epin,
# Thou king's pervery tame all you epion th
# ----
# iter 94000, loss: 48.261440
# ----
# wr poresd thin all will as
# Lord be non, you the vish that ook, no I treasting arouth to matuy butet and, a fom with this to droudy:
# Thee an the hart, our it treaves of the knand anth ourbel and hurnat
# ----
# iter 94100, loss: 48.345544
# ----
# ttere: hade
# Good sorform's to agare, from my lutit troughing's cas anly gowelf ante, it rooke whes Anw mevering
# tus men's cruch a frot trve beedisty a beoth my then hild fort:
# The of the came, higheen
# ----
# iter 94200, loss: 48.383932
# ----
# ou,
#
# INd,
# glak thou pescuge, ereet: I reerso; hansicu onit he isphakement shis then unceffore Andton me.
#
# TOLAF ENGENDY:
# Your, for, and Nawith the chapper: of the speand dows buentist'll repiadses wal
# ----
# iter 94300, loss: 48.459873
# ----
# tane canget of Loon shardin,
# Beor pes try, not msert sult:
# Turd?
#
# AnNRLEDEIO:
# I'd not temess
# Ho he corcule
# We hoiomary seakn besant's my wirm
# usetust; and tiflefore.
#
# OPHERREM:
# But go erssous thce to
# ----
# iter 94400, loss: 48.446463
# ----
# en tin these word restous hes tire evead wor breabdschart,
# Murder camise ceque my ety crack Soulje seakes so bal neniuld, wanthy, ged bempies care not be out wild to thie he sorrand. I pingo, sterpurl
# ----
# iter 94500, loss: 48.453465
# ----
# ows opad your the led bathandelidcang, mare, as rafts
# Than not to made make her the dody mo'w bood it of and to callakenteff, free brie,
# Somed theat: ance do foather thonn's wakt treme wort there.
#
# Gy
# ----
# iter 94600, loss: 48.501182
# ----
# ee you wet thear: sielinw to wike not you hat tons.
#
# PALISE: Hapt thing and thake pollent hove deacteot eblear withight, do hen the coOL' fronckl't bue an;
# For lose hor shet:
# Thal it, the tom up agot
# ----
# iter 94700, loss: 48.429938
# ----
# ot lave I caspence fiftll thou hathity
# Sereake with our the bove
# Hein my evet, my hare werebk:
# Hos nos ryay ow's Hee our woul ffied bes; the peow som cone, peds'd me'll ut Lillg
# There this ary thou me
# ----
# iter 94800, loss: 48.313465
# ----
# ut fur I virmive.
#
# HEMARY
# F HENIIT:
# That dyar day frumastone greorowim,
# But toI sust troum your not hap, me ambity;
# the wilf him coufful for hew be faied stire hak hate if the sore no acper all so mug
# ----
# iter 94900, loss: 48.270815
# ----
# adweer sond their whaurdy brok: knotht tale, his go twee, aldsibe true aglourer no ind ash, coogher', I epels my morneds my houly has, of taking thou yous mue,
# Mupt?
#
# PATOFAR:
# Areur.
#
# SeBR
# M:
# Sill wel
# ----
# iter 95000, loss: 48.351424
# ----
# ou, and faptet, entioughtald of not my pray't sest thy offer:
# Whee: I king beings: haine's with thou nos htiessare:
# Anet's come,
# Terrours alt as I whinos not thim amsping?
#
# SELINIUD:
# mear and if would
# ----
# iter 95100, loss: 48.438471
# ----
# ha dou Jond.
#
# ALVOAR:
# Cous shee the wombaen
# so come paim not dhile sho houth:
# Is eme artet cee:
# Co my gipe, eive shered thou seet sue;
# And do butir fane ald,
# Sond? ghou have there the well it semath n
# ----
# iter 95200, loss: 48.367705
# ----
# u tour no shamen,
# To and hy lleon wehoud dides mernow; bay,
# That
# Ded!
#
# KENG MANT OF WAUDE LAULELO:
# Your no Ceept the canped to word and;
# Iful in this upos estquyoket.
#
# OxSSATh'r and siememy beft this
# ----
# iter 95300, loss: 48.288461
# ----
# hasma tuept gract retlatind. By;auncome belcis tak mage wowowove Line the and me conquemice not sheith afuin tiest.
# Their a feited hie netrle of it sole; ank shis womink's love.
#
# TIDIS:
# Who, is We gor
# ----
# iter 95400, loss: 48.195746
# ----
# eart havet toobe rothton star the spreat.
#
# MALSAHIUS:
# Oed ferver man twack meth the side's fouther:
# And Tiadl--sithed core expean:
# Hos marve:
# Hut his arnoy hilk sipsond
# pration wors, fold, this ver pr
# ----
# iter 95500, loss: 48.254748
# ----
# at
# way, ang mone prath a will's mtroust holl pes, a berent of I hes thers
# bost in the pupter.
#
# TINDMOLH:
# Hot as ere, you,
# That dit, atem:
# whinse with greild by punce foll of thie her lorl,
# But I do sh
# ----
# iter 95600, loss: 48.216518
# ----
# om
# Condud bemy arty drier Oarer one this lush sows a I me fiangart,
# I.
#
# CATRES ASSSIUS:
# Ce mughtes Hownty
# Wolf her sese and wifm; atingins mathice go pray thas whe meace the fellich not book;
# As 'tsom
# ----
# iter 95700, loss: 48.336445
# ----
# le bye woll and truld Beat arume stamne, nos suen: Mircus a cay.
#
# SerThe muting,
# qurecrode'd hom my his ox weid forth, byell, hash. Who nolk witld aciumte, memeacteeth peack?
# No reake I lour, ther; th
# ----
# iter 95800, loss: 48.392830
# ----
# en til, dyat hould fake ou, powing;
# If in thy my lucure enping! TAard ours, atge in:
# A gaen, of whackine pre us ond I blacd.
#
# ICGARUD:
# But Hus upore I sorse,
# Oer with gord but and wiroTh is, aie nake
# ----
# iter 95900, loss: 48.502995
# ----
# havisty ut why lambell the prots. would hlame in that of whouk anvel an and them fith make he fus in flee, anists:
# Will thou we of Bardse, thie spioven:
# Pabreff.
#
# CQOIMACTENI:
# Wher fastlut in your hag
# ----
# iter 96000, loss: 48.344184
# ----
# iaght hear me
# Seave mang.
#
# BHAR OFLIO:
# Onougher.
#
# Fur what ass a lenenied he wald Stone:
# I wolsh! my myory,
# Whires, hous,
# Five to wheen,
# I that ampy.
#
# UNPERAS:
# But sekes hise would the wible wouls cul
# ----
# iter 96100, loss: 48.270968
# ----
# r sorenton and and confine with thankand eed wedles ever,
# And,
# Uot:
# Tleemser so than Preave cemposieet
# Ins your tood to ook ang to in beld hough,
# Unceath, I Phare the merpeance, whall
# And wessann Rown
# ----
# iter 96200, loss: 48.118640
# ----
# en wet' Hase day.
#
# DOLOFY:
# Whis ir.
#
# Marwe:
# There'd I lotter, you.
#
# HRUCHLOUS:
# She be, thiith hal hon my hes satht Gave timo'd tall by groweaniffor vare he love and ungaew ar kibk heels dested oo my b
# ----
# iter 96300, loss: 48.142809
# ----
# steas to-me a hasionce,t pramen bedy and berous in that nemend.
#
# Hid:
# kus, the rey
# Hice we atire butw and,
# As the pureffliln
# As,
# Wither find housh undier thes.
#
# TINCAS:
#
# JORSO AOCATr:
# Yought thy lay.
# ----
# iter 96400, loss: 48.198217
# ----
# eaghos, not with pro be,
# Brauld have thain mord;
# Ald soment boft Soatch
# Turdy
# nod tid, to die tre that folble your and ateed Sorrter spo menine comesy the urict sonduent your corn thy fall'd no, the r
# ----
# iter 96500, loss: 48.136479
# ----
# n of with mures with this tofe ponse,
# If mathout a beres lake an. my rearsosiobquis:
# Lobcucushie
# Forus own.
#
# TOVANE:
# Pancuip:
# To coursted and, well whincent;
# Theid not oat fattell vilmay speenp.
#
# YoOL
# ----
# iter 96600, loss: 48.214073
# ----
# INke,
# thy with weake
# Fiend, deap.
# Caustold a meand hive sore breefer,
# Tow kn, If on'd hew dis forsart It the
# gooth insibe well abe you whim som ance: zike I bears,
# Wit the mudiend be the lishart and i
# ----
# iter 96700, loss: 48.224059
# ----
# QUMO PrrAstred's the plion wet bat; phad, not whill wach my ofts aglent plood, beid: and cellus shoudsarest griglting dish ob;
# Thesed my sistrent what sing's, purty, compond dat.
#
# CETUCE:
# Shere
# Thou m
# ----
# iter 96800, loss: 48.246160
# ----
# thrs Seak you tuemingens sing:
# Non pake well ang neing you;
# Hod with of I wornot all Mare is have oave urle mare and the basbe;
# Sip.
#
# ThRUSNUS:
# Litly will go man net he blasind thou domes and,
# Pe woin
# ----
# iter 96900, loss: 48.179533
# ----
#  Sir here, contwist woughtece, agy ir, fichores it the ha not all, of will my plighbe be
# kin gayfed othey, that ullain tyen, now S's arrot?--
# Tawh liuthen ke,
# Teartey prapy.
# Nhe werrown, snomemed wase
# ----
# iter 97000, loss: 48.213175
# ----
# me's hence to jome Mail we magians lonk fullo ther-fire to not his hor thes he Baty-
# Anty,
# Whece.
#
# Fill wondonts with I all andeffe not of suce.
#
# RNk:
# I, mpersandtees
# maken and time:
# de'lst efoughol f
# ----
# iter 97100, loss: 48.108360
# ----
# ethe' toedir, beak this ssestr. I dar it womled.
#
# ORUS BEPA:
# No kin, dyou lomigris parnus, ad and thom Oper noth, my fwer, and gro chirist my cood
# Tleged are hinks,
# And ally for frucf'd their and with
# ----
# iter 97200, loss: 48.001768
# ----
# t our sall hemcicl sail of talin wand you ontter be on syeate
# Hed then tin swount, perpas thy pome;
# Is tillens messeralis, do you graar op woll to dorninger
#
# SABF Firly sill.
#
# ADOINO:
# A drithth, thair
# ----
# iter 97300, loss: 47.923195
# ----
# hou h song nod you,
# Heal ing do king
# Weve dice: a that duterthy'd
# Rossernod mooby:
# And.
#
# CUSt:
# Whithlire dreain witents of thes.
#
# DAUS VILLO:
# Pees, courid reals mave oum
# At, the toinge, geater surtion
# ----
# iter 97400, loss: 47.866577
# ----
# d hat I mand as wift wire, bod, youssy your dedht, stost go told.
#
# EMANAINC:
# Shasty neswerens in thy treat thou dus , likn To not of porroun us foos 'wal the woll velly to uvi day, our shom.
#
# TOMILO,:
# ----
# iter 97500, loss: 47.928153
# ----
# ear han, youid sith thou wife sistruines day maous.
#
# RORANA:
# Wher-cucefter the wors'ds swaves be weurden!
#
# DUDAUF hos have Brmar, dearle thap.
#
# Sispeare, Nows of now gyare my pearrell doon.
#
# KENCLATh
# ----
# iter 97600, loss: 47.877176
# ----
# y
# Lfon, I co wors wath of Eckerte,
# Of for bere't an fall you all?
# That
# I he sall's hiled gendserves'ws not priop,
# The pay that om the for for dtarmar:
# Mearsed Anat;
# And your do have fought
# And. I plan
# ----
# iter 97700, loss: 47.867125
# ----
# nd:
# Give shall I sharrd.
# Foun my 'NTge, the et my hare lell
# I wose man then could ritsus stescemang wittlemt.
#
# PAMASS:
# And withtmy shalf!
# A fash?
#
# ALLORY IN:
# Nou heak welimy wet to wed meakice as setp
# ----
# iter 97800, loss: 47.840224
# ----
# s, il and I cuxtult us with abe love and.
#
# Avereldst o'd in Cy the a vrustiroud we le'varng? houl there and gro a mow that et Phoust mey letins
# Hond;
# And agay my my bliocher betith magut ow coofer: I
# ----
# iter 97900, loss: 48.046888
# ----
# effror and bus you do the fillly hears sony. For blasdre my are oun arm I as thuss, If you he af'd hllowed
# thare wave drorur my dote you would in our harmurn's, tus have saws'd, and the a hor, Craibe
# ----
# iter 98000, loss: 48.042012
# ----
# ere weon tolf there?
#
# MAFANDUS:
# Handled of redires
# To moke quows to my hor upor steod ke, ghan Prace but Bud take Colcbeeare greatring withart wis frose fon hand thay mettrugent gxeead mese it deced a
# ----
# iter 98100, loss: 48.121588
# ----
#  arte to touh whie Bear'd this; Bither shar you my the to the dhig io hatse da bututh eakt to tonco.
#
# KING LEMART:
# She dosting, and Maither your dearm forbuce yous paliom sie man, sif fadam
# shey he a
# ----
# iter 98200, loss: 48.162212
# ----
# CERNCB:
# My Ry thoughings, anremes,
# But and love war tome, like cang. Wet your his gnast agl.
#
# VOOLLE:
# That your I widars
# good, wit ghee: at uss,
# Coost
# me aw hee
# Whice sirpin
# Forf?
# Fir, kive thee goaty
# ----
# iter 98300, loss: 48.234269
# ----
# at yy souted ang I wad son sofe bus, deeil's too and leaven, waish and Jearse'n theegches coulds to as huslent
# Dike all flishbrew a doungid, an,
# Soug we plostar,
# Yhee
# Se, will and the sall be to the i
# ----
# iter 98400, loss: 48.234745
# ----
# n, havered, and.
#
# CASRAS:
# I sorrull, ho mughin:
# I dod undy bang. To king sorn. Weoce bat ingud agt pre.
#
# BANTA:
# What ke
# Geen, olse:
# Bundy garty molanter, pros sut.
#
# OLI:
# An tre.
#
# ONCENTAN:
# Cage of wha
# ----
# iter 98500, loss: 48.218769
# ----
# ath bansie
# Moon plaright fore sincist lo have Lep, klich your ovet Ind Be beins I day turt ay bas the love, mike ach for;-y.
#
# SROINS:
# Abdlast for prather heechimbraln.
#
# CYere fol
# Tall,
# I, mome theee t
# ----
# iter 98600, loss: 48.276047
# ----
# our fooly saction then my to be,
# That le,
# Or arit,
# Ne pindses:
# But tibles woult soulf for the wours as and hiry theurn:
# Core, you ol hasay this glar' meses your Sipforlie
# Pad eos sweepunsed but and th
# ----
# iter 98700, loss: 48.209670
# ----
# kfing.
#
# LARK:
# Briest culder lold's with omey:
# For and fater as memint have nearw
# with houlad to doun this pety recsa erend of Antleace you dead hore, and, dhtile:
# Or, gllit haved, spo prime of sum cac
# ----
# iter 98800, loss: 48.092205
# ----
# e fre costeisomounsconceliid my would sford, gle ploves I'll shair a sway ad wey manoundody
# As wissens
# Triene
# Thence to deare ow you prath with thee
# Styop.
# Soule not sthop.
#
# KINK:
# Greaciod base as ler
# ----
# iter 98900, loss: 48.063954
# ----
# eth of his me,
# Tigho your dhy
# Seam and lowy surpiemiad knet: here ghill cave not reyows, co carmay:
# Pert an 'spion merhightre;
# Were be of mo forlilut coull as thooke
# And and have I not anch fatlet
# Rak
# ----
# iter 99000, loss: 48.124330
# ----
# em fisnuch it hildwer, corveitane ford.
#
# CRMYwEORINU ANN:
# But Iw puishand son dyece's Sill nlis But?
#
# Secin to heed
# mee; fifes you Nor'd, fife not lostile Say she your widle
# That moom,
# Lithes thesely
# ----
# iter 99100, loss: 48.223159
# ----
#  tir, cand heap.
#
# KENT ATRAMLO:
# Yo kans in: 'atgerends.
# Whes has ice hathy form moncere for thour dos and any hind thee, I shy so fleothers thy ciattsell Lfichaube an latwer: our kent thy guter'd wais
# ----
# iter 99200, loss: 48.158448
# ----
# ha hat wlle my agamp,
# Whou suph Love by Shes drom will no say you he with he bist fans of the diftiny say, as brabk be carly
# Takess
# He cingre, the wosbee:
# Thou the frexcelfey, Pave Gifelis Lirm at fiv
# ----
# iter 99300, loss: 48.060946
# ----
# ngoor hich haves nact? I hanncostase tame with hones merveig ou; not Cay, though itswers would Pepppean fon.
#
# AGECESE PIN OF YOLANY VOLIA:
#
# MISSA RONO:
# And and and lenclpingarv wiflleb:
# Wearty a rella
# ----
# iter 99400, loss: 47.979060
# ----
# fiet.
#
# Ferd not, the stall these mordsed your for thue, a Yovesers compin though hin!
# Hart truch whous; glaoke;
# Be withed it'w o'll on; as by soove by
# Dow tratio eas
# coug I huse of rechace.
#
# TRUSTER:
#
# ----
# iter 99500, loss: 48.031180
# ----
# nd beer shought
# Engirtad
# Meens share the galllep and the orr,
# No a core thow a the let her a do your woyeedt placked
# Tord plamnam
# Fike and novy freme the fast hore yatarlary:
# Yow entee the gerteechirg
# ----
# iter 99600, loss: 47.991666
# ----
# hathy upon thrue than thye!
#
# Seds noth.
#
# KINTESISTIA:
# Whel
# Thate suile thou sare to theemed: I there: chair are
# Whaid!
#
# ELVAK:
# Bllomsofted my dedceen truch golle, to be toverea situth tfoung my goll B
# ----
# iter 99700, loss: 48.119313
# ----
# tik, tfearm of mpents.
# Y moutn Joterling,, Soncond grord of a sall sucline, wid ese be;
# 'tolemispbousht you hap-
# Le peat would could he prave contre. To ow with of if;
# Take do knailt's tor.
#
# AOCLO:
# A
#
# ----
# iter 99800, loss: 48.177766
# ----
# e hour
# Hell
# Nongow masme, Taoden- ablus my off peave huce I thenoun wach you hance the wand hencert covest prouck,
# Dugh go perheed thee ath us and, you bores the psood Oax ood your a not! so, ant thy
# ----
# iter 99900, loss: 48.280154
# ----
# oth uilef of up-sie derse one be coather wifliny:
# Ricber.
#
# BRAR:
# Dhay meghin
# As should lifurmed?
#
# CREUS:
# Op awe now sidech undain where now turned whou the wifmer
# And the roug, ir coucet us quecmbello
# ----
# iter 100000, loss: 48.121253
# ----
# TIONCATHI:
# Nelvon
# ...
# For heak dow I Bryexancore thoth,
# Ast greet is to dey thim that hantg. Si
# ----
# iter 120400, loss: 47.252461
# ----
# with panded forpuon to gaithand as you.
# Uw, all siir bord briend ase:
# As netberesssper: hip us pookan a she renced the in to gramd
# Theis Tronce, at my heget form roungerd the
#
# BIPE:
#
# DUKE OF VOCKNN:
# A
# ----
# iter 120500, loss: 47.222139
# ----
# he reteh'
# Dy'rtons faist in a they forn't thishell bortre me.
#
# SILSSUS:
# My praysige spo the ceiz that shy is enown! and poan by deart formay Andos to futrowednage:
# 'l'st say in much faibk and lord.
#
# L
# ----
# iter 120600, loss: 47.301260
# ----
#  ham dost sunging
# Te whis ationd there itlees, the hindo.
#
# ALBOIS SABBINE:
# Nown a deavet
# Lur.
#
# TOSSIUS:
# Y'I; for and hendos my ar. Pere know, and sict not of that grought:
# And, at Ith mare manes to pl
# ----
# iter 120700, loss: 47.274385
# ----
# ou, hy tho, and belenc, bug
# To be
# poor shash,
# That be nos.
#
# PABALLALE:
# Caids, ow' flast ney, vilpimes and and camberingent hand,
# Soughtion houghtry;
# I hire of think
# And bar,
# Whingre!
#
# Thatt in the her
# ----
# iter 120800, loss: 47.328341
# ----
# ITht hase; in thy sereld I'll morty eirgher is in the dath all in ale fors, a here come, and a gith these of drear praise in whoy. So him now some your you cooke meme we prom not:
# But But itsong wemen
# ----
# iter 120900, loss: 47.288436
# ----
# y,
# Iffeor with my raywer he seend; down the dict of no of than inse, heme, thes I wanguinet set to our shiuls thy quat seoun'd I of with plords
# Taus out inceft frminess in preseT't, sol: Nownous
# Es ti
# ----
# iter 121000, loss: 47.337031
# ----
#  grake
# Maak five resolry,l steathy choris refore hey of with their cone, gun! I prithy sith,
# No hasbains hie bemp stor you tile a worde if gost the prilang the dostirs whiteit,
# Ar Muss nobgefell tood
#
# ----
# iter 121100, loss: 47.197867
# ----
# d,
# SI lather to hereffas- ente tough, for to thy soumf.
#
# Sim Colown san it thum woth men, whath you.
#
# AISTER:
# MO hild, but of you thou resert that swo unsore keat will icutsang make with to sich See's
# ----
# iter 121200, loss: 47.092082
# ----
# n, daoght and as have ames and steraust king: folf; by lifuciest usem.
#
# Thatt I of of my hatare lad fore.
#
# KEL
# O:
# bleny some in with youf be!
# Heer say toudang the hight, beis sait the heve bis in heav
# ----
# iter 121300, loss: 47.005343
# ----
# ou thae have longeave chee is whils.
#
# OLIULAR:
# Iw poncerffole
# I wilse my graje ploble the sere agay mand mor bugpeath a manire est the chant breipties, comporrowt combest
# noth be some thy wion canger
#
# ----
# iter 121400, loss: 46.973500
# ----
# n, have of withice formord
# this cady in
# Too of with well I wifilebs store
#
# DUDEROED:
# Will suchabike of must and a lord, Eyilk, by thut beace.
#
# ARPESALFID VONDEL:
# dre the saild jeand.
#
# TRJOLUCH ID:
# Thy
# ----
# iter 121500, loss: 47.032797
# ----
# thr and not agals, from this camch thise cageth tole, thant is youl meray us ape?
#
# QLOUDYCUS:
# It unstare, wive to whee, I conet: you cores, vore indser:
# Ehe woll; you hak him way: nee;
# Than arr:
# So id
# ----
# iter 121600, loss: 46.965063
# ----
# ou that vear yough wife pyer voreshers.
#
# RoAN:
# Peaden tleak surcung tret me tikion clade thee
# Pee to ne' pronnds's no you theurt Saster forlowringo: I dos mone.
#
# OLONMESTART:
# Had'll me whor the play,
# ----
# iter 121700, loss: 46.980985
# ----
# d yftare ligentettes plaaid lugh
# Tho my bittrent
# To to your;
# Un.
#
# Furs looe this, manal' are, and had not go are you arolt: corests, a with peardentt fallr
# And jlaxt; is he kids me love
# Blighy all whe
# ----
# iter 121800, loss: 46.950369
# ----
# o thoth our;
# Comonarn
# Mugoth her undour onguntre has dufrenn, will my of a him and
# Ancmamy;
# The Onous agad.
# But surent woy I prish meen:
# I would vood, foull,
# Ar
# Aravid,
# Coskadeny his fullet mis sherre
# ----
# iter 121900, loss: 47.173508
# ----
#
#
# Ayvut dath bryinging mpont, no
# Tich of the uraves but mege:
# Whay your havene and that deet I wore while hechle.
#
# NELOFANIO:
# Whak I sis goods
# I fait da sance
# I love wa in a provu
# Thus have and aldore
# ----
# iter 122000, loss: 47.158153
# ----
# hathre.
#
# KENTf LUUS:
# The coufford arous what paishore;
# Ore--ums, with of their, I douise of saipes my reo this, wablead;
# If somispsers have Andain and furay, houst are esed your mavenoms.
# Whace them t
# ----
# iter 122100, loss: 47.220177
# ----
# have takes sisurpolfopsbrept fear to will thyy bried not with gine cerin ther Ges well his knomm.
#
# Fare?
# And 'ver your:
# Was soul's fie ambelinad;
# And meed to.
# DU
# TELRUSDO:
# For and oun'd, bo my fame:
# I
# ----
# iter 122200, loss: 47.301050
# ----
# r homsilto I omr why deot, not Pricher so thing teer and beachcutio in doon
# Whemracn, there hat doin
# To knit.
#
# MARGARLON:
# I maty.
#
# CLEDEMORY:
# Whim out king I'll now prayoug daubk be confalfobout his a
# ----
# iter 122300, loss: 47.355411
# ----
# atherers.
# I ablecthely all with':
# A diest but him
# A vatroneght the culfilt,
# Anes the's floganced a bot exquese of all then peen.
# Frilld ous awed.
#
# LEONUS:
# If,.
#  a dous
# And to ad ca facnoutern, and our
# ----
# iter 122400, loss: 47.381209
# ----
# y,
# Follflen
#
# BOFr:
# A le lastlatiore coighore come'st:
# Is he dome ouf of them zird, it my seath treeffen hand the deation with thechen forght,
# Hadliake.
#
# NUSSARDUS:
# my, and distay't our Is trum I bryan
# ----
# iter 122500, loss: 47.378406
# ----
# w, Wild, ped lo my mie, it,
# Ancers, the mile to pringenlentles as dits theis,
# The be, are our fallver vor, sold boose; I rom eress:
# EG in inser would with to-duver
# I' is agry.
#
# ANY BETS:
# A'll his good
# ----
# iter 122600, loss: 47.396715
# ----
# :
# Oll flanaeshen in thear now,
# Cainating'd knowing.
#
# KENP fount:
# No losd.
#
# MIAGLA:
# What a gotst'dladesh knotersare;
# Le would sanding and st as me it no my
# By
# Seds!:
# Ase hers he good tham the Gendry no
# ----
# iter 122700, loss: 47.342374
# ----
# ai my I stoles ourn my, ir age
# And hirnot'd our coull he servery, and to you the haved.
# 'Stathauntlin pray
# dyake the look of not the of I bley griblet,
# Weat unlagreath, of whis semin.
#
# FALUTNEET:
# Harm
# ----
# iter 122800, loss: 47.199071
# ----
# Astount youn porlder:
# This Tald, on I hat IS hak dendy
# By my amputseay,
# Thing outhing no pores: he hie now rick yow east swealt hearisuch tive
# What stall be way,
# Them neake et' her dnount Pall; undone
# ----
# iter 122900, loss: 47.224163
# ----
# Mathen Pout conever Onee the cairs.
#
# MALLELUSE:
# Wearsint,
# Where'd it, thou lith thou thuch. se thre day in le meath; anl'sds. Thus Truche, and amy and have
# Sied Sair,
# Of:
# By thraishised whry prother c
# ----
# iter 123000, loss: 47.254039
# ----
# :
# Yeseds or
# To in call Frooked merount in Byen as to the cueseI fuolghow.
# Ah us, dowr,
# But ager ro treat, meed,
# But her leave
# The gaighen and treak seavusno.
#
# FARDA:
# Be.
#
# AINFER:
# Wheires and pance a c
# ----
# iter 123100, loss: 47.356068
# ----
# att wose;
# Tle camo.
#
# ONGELLO:
# Che pive would, all of deathchreds, pecante eling dos now quece off for her ay,
# To as you I lood of his premaink indolt,
# To witht they lold fcime thou saps, for fore the
# ----
# iter 123200, loss: 47.285127
# ----
# nd aress our spok,
# Thery: Cence sumpis, I face these be? my hair seart oul I lentre, his sister
# But agr, pactarbhone son ust to there be, it tidly parm groutter thou dot word sellsios as shault,
# Glide
# ----
# iter 123300, loss: 47.230648
# ----
# hy wtay deniln as lail,
#
# VASSIUS LOVAR:
# But thereur to het dit kmes beat thou wire; fore frallin, the sir,
# Brecuty of the im trean wifr't he her shas sebrea! suce?
#
# DUCHELS:
# Ank her-.
# Dith to me whoon
# ----
# iter 123400, loss: 47.120797
# ----
# hap eall aked not lind redliel.'
#
# ARGELER:
# Is le
# To Steet them now munk, whol etand ofr,
# And of a turas be hy gent manty the the mimman the corest.
# Whe brigleep plaus herld I wit he we be, me; I would
# ----
# iter 123500, loss: 47.136046
# ----
# ere bam, it me it wood swelvatr,
# And amisscere leal iculd for shast poblagep: pooch whateur-me
# Clathiiingy and sand truch or day; toltad to it, shose, He vion whou haxk whan get: the senferand
# And wel
# ----
# iter 123600, loss: 47.117196
# ----
# ry,
#
# GENAEL:
# Not 'dairfill ro we your hear our no exmegisstitient'd not mant. To all; this, tlam, as not stonter: stain barough: we shithel his for in thie me,
# Muve you wast. these: sceaider: benow, t
# ----
# iter 123700, loss: 47.251600
# ----
# ath thim poat is spealth cay yfur ever?
#
# HERNIAR:
# Noug: no kers not ford a father the ghone tholos, do
# Then spoons was mows I fire; ag. Ey hos mauster for bad.
#
# COTRUS:
# Steo hithmes,
# I with,
# O'll him
# ----
# iter 123800, loss: 47.330968
# ----
#  frook:
# Frables to I a sha hande, do of Ip make: have you I have in trays ald of thy go my lerder take and hapt depwersiago vilglessd, I vincation the treomen;
# Like the uplave pamor, I dobat them chan
# ----
# iter 123900, loss: 47.373047
# ----
# eat he bith one, my lotiome: with,
# A! she
# for episus putes reiltadn'll a deed not sowh and mones aril;
# Dhecrais everito.
#
# VALMANELVIUS:
# Mookiest I brits I with lovy.
#
# PEBROOF:
# Whing shadstur,
# Wet hap
#
# ----
# iter 124000, loss: 47.241260
# ----
# ll fled nom hat sis aike I do Muround'd thy some
# Tithist, desture. Were as morul her shall sorls conine
# Whan threasting to blase,
#
# Youghaun hould thate fat my that is at I prist a, but know of fere,
# W
# ----
# iter 124100, loss: 47.179862
# ----
# AMANTINC:
# I' the have you hau enfind's hould, san wet me bood thee to go not wast sinds, eas estay an she mees the arust our tanin:
# Mail; the to all s've ourds.
#
# KING OR:
# Shryence
# with fese a lold a d
# ----
# iter 124200, loss: 47.047236
# ----
# tha hrum sice to estrath have dhar; see in hound in eathy? a's your an erimmest this enich uxclom macko not obe it matury, Lose.
#
# WENF OF PAVONDA:
# But be derilk mase.
#
# KING NCE:
# Be woury: dines.
#
# FIUS
# ----
# iter 124300, loss: 47.099439
# ----
# hemy, othel mentech,
# Than, a hand in amerus ganes? if all hillus ams, I whry to my from theme hish yse greveen: hours? thy eok wenle whrorl shought
# For am deneact hey with wouldcees.
#
# TAVELANY:
# Tare s
# ----
# iter 124400, loss: 47.140990
# ----
# tAyest are, barm refef is shusare.
#
# OLANA:
# Cone in
# Nor Severt in you it!
#
# Semel wers,
# Now and.
#
# KENTW HARIA:
# Nod.
#
# Shere
# Toe.
# Hed!
#
# CRERTER:
# A moy's, in gost no my a wouelord, this be the wald mepushi
# ----
# iter 124500, loss: 47.089031
# ----
# US:
# I:
# Thit mould.
#
# SaEF thee sopens are, ibgat, can it then there, ay this trouch her, hish manet than Jund of but hore mear the mordion greact ain Fath, beed for lordg,
# Woury fawse, Frence my wofr?
# ----
# iter 124600, loss: 47.168102
# ----
# nbme, of be wifed pantay,
# I my prown, seest our that siired these howd and famer and a touse not dousty, muse five beance,
# And readsdefor upo not bloo I fair exare on shim and we a witht
# Till hearte'b
# ----
# iter 124700, loss: 47.155936
# ----
# in you, them by quack, my wiklisce by myllad for prowglon thy heak erarp feir unoushenth mesed ground Forca an plinggess as and love; goodemy man fulle, quits.
#
# LANS:
# As you Large, worl what houstring
# ----
# iter 124800, loss: 47.210422
# ----
# t
# FioK O:
# Ib tire tnyong might you brousned not in vore berosper theon,
# Nor Tor'd not the bas yfild tord the will my for not he to-bey highd it fall your and wet thew fair as agral stoun, did, to los
# ----
# iter 124900, loss: 47.174233
# ----
# ay, I gunscunt,
# Unele now Pispances as could Angiad aim epon, sat, yild and and a fould
# Lord, beers
# Wired so sbeane'w Pessperent a dicufe in rech maning them.
#
# TJOUSIATR ANTOV:
# Her in pay do co shis w
# ----
# iter 125000, loss: 47.214483
# ----
# r: surm. Bur menattell Yhee nather my lo!
#
# CLATHESSIDUS:
# Nay to all me unlalkst frime if tord the that tonduck chir,
# How in, thay a wich sie thwe.
#
# SILIO:
# I would stall'd un.
#
# PIVIINGI ANIO A:
# Burs, w
# ----
# iter 125100, loss: 47.078800
# ----
# eve rutly lembow.
#
# ANTRUDH:
# If where, it swaithen sheen sike, Pechy I some Hes me peent I prook derann chadmast them wad be someto theannove mee I love of now you hailn
# Hace
# Thighen: He king,
# Le wownd
# ----
# iter 125200, loss: 46.975512
# ----
# e's stre my dutin, aved mighere or ceevonfire and foirted
# Make Heisty coos wher'll I and me bester?
#
# LOEG ATUT:
# Dy mare etter.
#
# Serell bE hich her, I hove and aead behines from, are be pedare men that
# ----
# iter 125300, loss: 46.882353
# ----
# was
#  at, of withare ban there?
#
# DESTOBOF LAUB IA:
# Whor itsfess: her to in groth of Parfeist.
# Sirt hid
# Viged
# Loth my
# Firn limientaitnobe true and nand will gutk, by she wear mobroth thab contey then mc
# ----
# iter 125400, loss: 46.857343
# ----
# oth his with rit.
#
# Fy ICHIO:
# It hig,
# She lood: tverelont are mpam and dace, incu to to menton these this, be lead rade id we fraintet courther a fult sond dismast?
#
# OPRKSTONO:
# Then I vuriont all goene
# ----
# iter 125500, loss: 46.913029
# ----
# nd or Ald's Grouctyerean.
# To gohor and,
# But have an, stelispeiss,
# Whrirty
# Well soudo wefoullet ack; have you swand, enat heny Re purtsost utodr owront ame os that thye mustaseling in to thou as twey e
# ----
# iter 125600, loss: 46.835549
# ----
# he caguct mat sittir
# And from dother:
# By to gray; resery, it of have not of Noens,
# Your of ceed and thou hove me,
# do which mughind seath and, whis detold snceal
# Whol nive hey thou tee, to that foot no
# ----
# iter 125700, loss: 46.866161
# ----
# hene that othald Opgestigyould sthason, khie; and I quencownce, and hiressond think my their fass courts muntinod,
# Br.
#
# HIAGERISIUD:
# Ivelf ay; fith, of fere.
#
# COBILIO:
# To graceet And kint latht the we
# ----
# iter 125800, loss: 46.823014
# ----
# nd his his fcom my dazep would and dyaid they it whay,
# Sid troukt of river' and and Sondoll:
# Mike thowneed!
# Youn hasp, own.
#
# BEFLUN:
# So nor thele your my bus of pient opinubly kicterare will be well a
# ----
# iter 125900, loss: 47.048100
# ----
# bre at marring bo m; mive gantle gith refull unout you, stauspur's mutwe:
# Hane Stlay to for hiep.
#
# FESTARY:
# Lo all roum owny cortw in quen, ere greming stalto Senceld on My.
#
# CILUSELINE:
# And love I fr
# ----
# iter 126000, loss: 47.075631
# ----
# nd you hos mank ofnsoss thy bast.
# QULY:
# I Caind:
# What a gicloun he woot, besent fift to knour that you dobgy hib dot?
#
# STEENRIO:
# Were a selesst, mily. I would misting-sealdconder the arrlas ere wet m
# ----
# iter 126100, loss: 47.110567
# ----
# : ain ow pare cheace thal
# Is to nearttramy then take bescome thereer see chrult blingishiles dim,
# way f o say I I will so get inblitwer, beither we indefer our paild thintay listruet, panding on thy f
# ----
# iter 126200, loss: 47.191753
# ----
# ea hilld loting Lake ees.
#
# PRENINF for
# She hord and the ruth farl!
# Serciins:
# Lutly.
#
# CONPUSITA:
# Duch morgizeth: daim fin ale see. Singlnour as of the hasiltres batingody raamithy;'d wik dey all,
# If an
# ----
# iter 126300, loss: 47.229324
# ----
# ATING:
# But by not musties thehe dead that and theegunt
# Corce 'nage ero sermay rowr:
# Of Mase of a plother asnoy, and ever her and pan, in.
#
# Farous fall, the ionthe the bithen waway.
#
# DUKE VARGO:
# undis
# ----
# iter 126400, loss: 47.274631
# ----
# kie, the the mery uperar ay that Ta ching apaland do-que kise.: I dismameny dos them of Dursaremy,
# SoI by a klit dite, baakings he lave Cortheres
# As whe stenver fame ligy, vill eeth, the prund,
# And sh
# ----
# iter 126500, loss: 47.272931
# ----
# not tore knor mond ingland,
# Hoys,
# The blicky ley, and her, ang I mentech exan in and we a dad, in say the bryatier of dembo.
#
# THANF LETHESSERDI:
# Lor the delly id be at I withen and dyoa; go call.
#
# COT
# ----
# iter 126600, loss: 47.288333
# ----
# er ipp
# Oid, beloos:
# Whation eaft all ffoinesw, then you out of catting?
# Nour'd fim of eptabcos,
# Fuffore.
#
# ORES:
# Noth my seed hap.
#
# LUMENIALIN:
# It I plangs
# Thecruss,
# My plestor;
# Go thee beas, his not h
# ----
# iter 126700, loss: 47.230565
# ----
# ou, ind,
# Whose your Heacnes'd thar in my ven dight?
#
# THACA:
# Them he wafe anencess I well hath lall enistion my haved
# Thus are 'all a prord ephave supfivenle, make hat ferfture shall face nove and doth
# ----
# iter 126800, loss: 47.095355
# ----
# le'l I wass cout of trum the wasty spineds, and she grice, a pell's ban
# lofes'd arm them, and come:
# Lan the hasell not but out noth frim all,
# And stid setther
# ToOght
# I' thad, sesels! bing o, If seen.
# ----
# iter 126900, loss: 47.114878
# ----
# aw, you
# Mawneet me brore greet you, to pintth to
# Yould quasned shirtt geed inguw hery you devers prind wif toull good toguth our store I llinler.
#
# Syou to hath oun as sheen aer: bom you henes Mavery.
#
# ----
# iter 127000, loss: 47.140244
